# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def log(x):
    return (1/(1+np.exp(-x)))

# %%
x = np.arange(-20,20,0.01)
y = log(x)

# %%
plt.plot(x, y)

# %%
def bin_cross_entrop(y, label):
    return(label*np.log(y) - (1-label)*np.log(1-y))

# %%
np.log(0)
# Out:
# C:\Users\rafal.wojcik\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.
# -inf

# %%
loss_1 = bin_cross_entrop(y, 1)
loss_0 = bin_cross_entrop(y, 0)

# %%
plt.figure(figsize=(12,10))
plt.plot(y, loss_1, linewidth=3, label='label 1')
plt.plot(y, loss_0, linewidth=3, label='label 0')
plt.legend(loc='upper left', borderpad=1, fontsize=18)
plt.show()

# %% [markdown]
# dervative of Logistic Function:
# - g(x) = 1 / 1 + e (-x)
# - g'(x) = g(x)*(1-g(x))
